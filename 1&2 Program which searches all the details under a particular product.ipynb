# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product name to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# importing required libraries.
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
#connecting the web driver.
driver=webdriver.Chrome(r'C:\Program Files (x86)\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.amazon.in')

# %%
#finding the search bar and filling the product name
search_bar = driver.find_element_by_id("twotabsearchtextbox")    
search_bar.clear()                                               
search_bar.send_keys(input('Enter the product name:\n'))
# Out:
# Enter the product name:
# drilling machine

# %%
#finding the search button and clicking
search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')       
search_button.click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a dataframe and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#creating empty list
Brand=[]
Product=[]
Rating=[]
No_of_rating=[]
Price=[]
Return_Exchange=[]
Availability=[]
Other_details=[]
Product_url=[]

# %%
#page 1
Url=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
href_url_1=[]

for i in Url:
    href_url_1.append(i.get_attribute("href"))
    
for url in href_url_1:
    driver.get(url)
    
    #fetching brand details
    try:
        brand=driver.find_element_by_xpath('//*[@id="bylineInfo"]')
        Brand.append(brand.text.replace("Brand"," "))
    except NoSuchElementException:
        Brand.append('-')
     #fetching product details   
    try:
        product=driver.find_element_by_xpath('//*[@id="productTitle"]')
        Product.append(product.text)
    except NoSuchElementException:
        Product.append('-')
    #fetching rating details
    try:
        rating_=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']").click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Rating.append(rating.text)
    except NoSuchElementException as e:
        Rating.append('-')
    #fetching no of rating details    
    try:
        ratings=driver.find_element_by_xpath('//*[@id="acrCustomerReviewText"]')
        No_of_rating.append(ratings.text)
    except NoSuchElementException:
        No_of_rating.append('-')
    #fetching price details    
    try:
        price=driver.find_element_by_xpath('//*[@id="priceblock_ourprice"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
    #fetching exchange details    
    try:
        Exchange=driver.find_element_by_xpath('//*[@id="icon-farm-container"]/div/div[1]/span/div[2]/a')
        Return_Exchange.append(Exchange.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
    #fetching availability details    
    try:
        availability=driver.find_element_by_xpath('//*[@id="availability"]/span')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')
    #fetching other details    
    try:
        details=driver.find_element_by_xpath('//*[@id="feature-bullets"]/ul')
        Other_details.append(details.text.replace("\n"," "))
    except NoSuchElementException:
        Other_details.append('-')
    #fetching product details
    try:
        Name_of_pro=driver.find_element_by_id('.//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]/a').text
        Product_url.append(title.get_attribute('href'))
    except NoSuchElementException as e:
        Product_url.append("-")
    
time.sleep(3)

# %%
#searching and clicking the page 2
search_button=driver.find_element_by_id("nav-search-submit-text")
search_button.click()
next_button=driver.find_elements_by_xpath("//li[@class='a-normal']/a")
for s in next_button:
    if s.text=='2':
        s.click()
        break
        
time.sleep(3)

# %%
#page 2
Url=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
href_url_2=[]

for i in Url:
    href_url_2.append(i.get_attribute("href"))
    
for url in href_url_2:
    driver.get(url)
    
    #fetching brand details
    try:
        brand=driver.find_element_by_xpath('//*[@id="bylineInfo"]')
        Brand.append(brand.text.replace("Brand"," "))
    except NoSuchElementException:
        Brand.append('-')
     #fetching product details   
    try:
        product=driver.find_element_by_xpath('//*[@id="productTitle"]')
        Product.append(product.text)
    except NoSuchElementException:
        Product.append('-')
    #fetching rating details
    try:
        rating_=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']").click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Rating.append(rating.text)
    except NoSuchElementException as e:
        Rating.append('-')
    #fetching no of rating details    
    try:
        ratings=driver.find_element_by_xpath('//*[@id="acrCustomerReviewText"]')
        No_of_rating.append(ratings.text)
    except NoSuchElementException:
        No_of_rating.append('-')
    #fetching price details    
    try:
        price=driver.find_element_by_xpath('//*[@id="priceblock_ourprice"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
    #fetching exchange details    
    try:
        Exchange=driver.find_element_by_xpath('//*[@id="icon-farm-container"]/div/div[1]/span/div[2]/a')
        Return_Exchange.append(Exchange.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
    #fetching availability details    
    try:
        availability=driver.find_element_by_xpath('//*[@id="availability"]/span')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')
    #fetching other details    
    try:
        details=driver.find_element_by_xpath('//*[@id="feature-bullets"]/ul')
        Other_details.append(details.text.replace("\n"," "))
    except NoSuchElementException:
        Other_details.append('-')
    #fetching product details
    try:
        Name_of_pro=driver.find_element_by_id('.//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]/a').text
        Product_url.append(title.get_attribute('href'))
    except NoSuchElementException as e:
        Product_url.append("-")
    
time.sleep(3)

# %%
#searching and clicking the page 3
search_button=driver.find_element_by_id("nav-search-submit-text")
search_button.click()
next_button=driver.find_elements_by_xpath("//li[@class='a-normal']/a")
for s in next_button:
    if s.text=='3':
        s.click()
        break
time.sleep(3)

# %%
#page 3
Url=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
href_url_3=[]

for i in Url:
    href_url_3.append(i.get_attribute("href"))
    
for url in href_url_3:
    driver.get(url)
    
    #fetching brand details
    try:
        brand=driver.find_element_by_xpath('//*[@id="bylineInfo"]')
        Brand.append(brand.text.replace("Brand"," "))
    except NoSuchElementException:
        Brand.append('-')
     #fetching product details   
    try:
        product=driver.find_element_by_xpath('//*[@id="productTitle"]')
        Product.append(product.text)
    except NoSuchElementException:
        Product.append('-')
    #fetching rating details
    try:
        rating_=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']").click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Rating.append(rating.text)
    except NoSuchElementException as e:
        Rating.append('-')
    #fetching no of rating details    
    try:
        ratings=driver.find_element_by_xpath('//*[@id="acrCustomerReviewText"]')
        No_of_rating.append(ratings.text)
    except NoSuchElementException:
        No_of_rating.append('-')
    #fetching price details    
    try:
        price=driver.find_element_by_xpath('//*[@id="priceblock_ourprice"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
    #fetching exchange details    
    try:
        Exchange=driver.find_element_by_xpath('//*[@id="icon-farm-container"]/div/div[1]/span/div[2]/a')
        Return_Exchange.append(Exchange.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
    #fetching availability details    
    try:
        availability=driver.find_element_by_xpath('//*[@id="availability"]/span')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')
    #fetching other details    
    try:
        details=driver.find_element_by_xpath('//*[@id="feature-bullets"]/ul')
        Other_details.append(details.text.replace("\n"," "))
    except NoSuchElementException:
        Other_details.append('-')
    #fetching product details
    try:
        Name_of_pro=driver.find_element_by_id('.//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]/a').text
        Product_url.append(title.get_attribute('href'))
    except NoSuchElementException as e:
        Product_url.append("-")
    

time.sleep(3)

# %%
#creating dataset
Drilling_Machines=pd.DataFrame({})
Drilling_Machines['Brand']=Brand
Drilling_Machines['Product']=Product
Drilling_Machines['Rating']=Rating
Drilling_Machines['No_of_rating']=No_of_rating
Drilling_Machines['Price']=Price
Drilling_Machines['Return_Exchange']=Return_Exchange
Drilling_Machines['Availability']=Availability
Drilling_Machines['Other_details']=Other_details
Drilling_Machines['Product_url']=Product_url

# %%
#dataset
Drilling_Machines
# Out:
#                                     Brand  \
# 0                          : BLACK+DECKER
# 1                          : BLACK+DECKER
# 2                               : Stanley
# 3                         : Golden Bullet
# 4                 Visit the Cheston Store
# ..                                    ...
# 176   : Arna INGCO POWERTOOLS & HANDTOOLS
# 177                              : Kelexx
# 178                              : Kelexx
# 179                 Visit the AEGON Store
# 180                 Visit the AEGON Store
#
#                                                Product        Rating  \
# 0    BLACK+DECKER HD555KA50 550W 13mm Variable Spee...  4.2 out of 5
# 1    BLACK+DECKER HD555KMPR-B1 13mm 550Watt Hammer ...  4.1 out of 5
# 2    STANLEY SDH600KV 13mm 600Watt Hammer Drill and...  4.3 out of 5
# 3    Golden Bullet HI93 600W 13mm Reversible Impact...  3.8 out of 5
# 4    Cheston 10mm Powerful Drill Machine for Wall, ...  3.7 out of 5
# ..                                                 ...           ...
# 176  INGCO POWERTOOLS & HANDTOOLS Air Impact Wrench...    5 out of 5
# 177  Kelexx Electric High-Pressure Airless Spray Gu...  3.6 out of 5
# 178  Kelexx Electric High-Pressure Airless Spray Gu...  3.6 out of 5
# 179  Aegon Ah810 Heavy Duty Professional 5kg Breake...  3.7 out of 5
# 180  Aegon Ah810 Heavy Duty Professional 5kg Breake...  3.7 out of 5
#
#       No_of_rating       Price      Return_Exchange  \
# 0    1,577 ratings  ₹ 2,697.00                    -
# 1       94 ratings           -                    -
# 2      189 ratings           -                    -
# 3      708 ratings  ₹ 1,599.00                    -
# 4    1,550 ratings    ₹ 999.00                    -
# ..             ...         ...                  ...
# 176      2 ratings  ₹ 5,099.00   10 Days Returnable
# 177     10 ratings  ₹ 2,499.00  10 Days Replacement
# 178     10 ratings  ₹ 2,499.00  10 Days Replacement
# 179     52 ratings  ₹ 4,199.00                    -
# 180     52 ratings  ₹ 4,199.00                    -
#
#                     Availability  \
# 0    In stock on April 30, 2021.
# 1                      In stock.
# 2                      In stock.
# 3                      In stock.
# 4                      In stock.
# ..                           ...
# 176                    In stock.
# 177                    In stock.
# 178                    In stock.
# 179                    In stock.
# 180                    In stock.
#
#                                          Other_details Product_url
# 0    Drill Wattage: 550 watts, Operating Voltage: 2...           -
# 1    Comes with 100 pieces of Drill, accessory and ...           -
# 2    Comes with 13 pieces of Drill, accessory and h...           -
# 3    Power 600 W; Chuck capacity:13mm; Speed 0-2600...           -
# 4    5 pcs wall bits included in the combo for wall...           -
# ..                                                 ...         ...
# 176  Square drive:12.5mm(1/2"") - No-load speed:700...           -
# 177  Simple one-touch operation cuts your time and ...           -
# 178  Simple one-touch operation cuts your time and ...           -
# 179  POWERFUL MOTOR: This 900-Watt demolition hamme...           -
# 180  POWERFUL MOTOR: This 900-Watt demolition hamme...           -
#
# [181 rows x 9 columns]

# %%
#saving to csv file
Drilling_Machines.to_csv("Drilling_Machines.csv")
